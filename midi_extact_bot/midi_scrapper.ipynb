# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from time import sleep
from web_list import website_list

# %%
# %%time

# specify driver directory
selenium_user_path = '~/Chromedriver/chromedriver_win32/chromedriver' # Specify exact path to Selenium ChromeDriver directory

for website in website_list:
    # specify output directory
    options = Options()
    options.add_experimental_option('prefs', {
        "download.default_directory": r'C:\Specify\Download\MIDIfile\Directory\Path',  # Change default directory for downloads
        "download.prompt_for_download": False, 
        "download.directory_upgrade": True,})
    driver = webdriver.Chrome(path, options=options)
    # intialize driver
    driver.get(website)

    # Find all song links 
    song_links = driver.find_elements(By.CSS_SELECTOR, '.artist-song-cell a') # the actual CSS eleements 

    # Save href attributes (URLs) of song links into a list
    song_urls = [link.get_attribute('href') for link in song_links] # href is an attribute in the code element

    for url in song_urls:
        # Open song page
        driver.get(url)

        try: 
            # Locate download button and click 
            download_button = driver.find_element(By.ID, 'downloadmidi') # the actual id element
            download_button.click()
            # Wait for the download to complete before proceeding to the next song
            sleep(5) 
            print('File Downloaded!')
        except:
            print('Failed to download!')
            
    # stop the driver 
    driver.quit()
# Out:
# <timed exec>:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# File Downloaded!
# ...
